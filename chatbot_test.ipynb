# %% [markdown]
# # KoGPT2 모델을 이용하여 보다 자연스러운 챗봇 만들어보기

# %% [markdown]
# ## 1. 데이터셋 가져오기

# %%
import pandas as pd
import re
import urllib.request

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1-1. Chatbot_data
# 출처 : https://github.com/songys/Chatbot_data

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/songys/Chatbot_data/master/ChatbotData.csv", filename="ChatBotData.csv")
cbdata_df = pd.read_csv('ChatBotData.csv')
cbdata_df.head()
# Out:
#                  Q            A  label
# 0           12시 땡!   하루가 또 가네요.      0
# 1      1지망 학교 떨어졌어    위로해 드립니다.      0
# 2     3박4일 놀러가고 싶다  여행은 언제나 좋죠.      0
# 3  3박4일 정도 놀러가고 싶다  여행은 언제나 좋죠.      0
# 4          PPL 심하네   눈살이 찌푸려지죠.      0

# %% [markdown]
# ### 1-2. 트위터에서 수집 및 정제한 대화 시나리오
#
# 출처 : [트위터에서 수집 및 정제한 대화 시나리오 - AI Hub](https://aihub.or.kr/opendata/keti-data/recognition-laguage/KETI-02-008)

# %%
tt_df = pd.read_excel('/content/drive/MyDrive/cd_ai/s4p/twitter_talk.xlsx')
tt_df.head()

# %%
tt_df = tt_df.dropna(axis='columns', how="all")
tt_df.head()

# %%
len(tt_df.columns)
# Out:
# 83

# %%
[tt_df.iloc[0, 0], tt_df.iloc[0, 1]]
# Out:
# ['기계식 키보드 써보고 싶어요.', '싼 것도 많던데 써보세요. 정말 좋아요.']

# %%
columns = ['Q', 'A', 'label']
twitter_talk = pd.DataFrame(columns=columns)

for row in range(len(tt_df.index)):
  if row % 500 == 0: print(f'row : {row}')
  for col in range(len(tt_df.columns)):
    if col+1 == len(tt_df.columns):
      break
    if pd.isna(tt_df.iloc[row, col+1]):
      break
    sent_couple = pd.DataFrame([[tt_df.iloc[row, col], tt_df.iloc[row, col+1], 0]], columns=columns)
    twitter_talk = twitter_talk.append(sent_couple, ignore_index=True)
# Out:
# row : 0
# row : 500
# row : 1000
# row : 1500

# %%
twitter_talk.head()
# Out:
#                                    Q                                  A label
# 0                   기계식 키보드 써보고 싶어요.             싼 것도 많던데 써보세요. 정말 좋아요.     0
# 1             싼 것도 많던데 써보세요. 정말 좋아요.  싼 것도 있나요? 예전에 봤을 땐 다 10만 원이 넘던데요.     0
# 2  싼 것도 있나요? 예전에 봤을 땐 다 10만 원이 넘던데요.                  이거 쓰는데 예쁘고 딸깍거려요.     0
# 3                  이거 쓰는데 예쁘고 딸깍거려요.                         우와 진짜 예뻐요.     0
# 4                         우와 진짜 예뻐요.                        불 끄면 더 예뻐요.     0

# %% [markdown]
# ### 1-3. 한국어 감정 정보가 포함된 연속적 대화 데이터셋
#
# 출처 : [한국어 감정 정보가 포함된 연속적 대화 데이터셋 - AI Hub](https://aihub.or.kr/opendata/keti-data/recognition-laguage/KETI-02-010)

# %%
ket_df = pd.read_excel('/content/drive/MyDrive/cd_ai/s4p/kor_emo_talk.xlsx')
ket_df.head()
# Out:
#   dialog #                                            발화  감정
# 0        S          아 진짜! 사무실에서 피지 말라니깐! 간접흡연이 얼마나 안좋은데!  분노
# 1      NaN  그럼 직접흡연하는 난 얼마나 안좋겠니? 안그래? 보면 꼭... 지 생각만 하고.  혐오
# 2      NaN                                       손님 왔어요.  중립
# 3      NaN                                       손님? 누구?  중립
# 4      NaN                                몰라요. 팀장님 친구래요.  중립

# %%
[ket_df.iloc[0, 1], ket_df.iloc[1, 1]]
# Out:
# ['아 진짜! 사무실에서 피지 말라니깐! 간접흡연이 얼마나 안좋은데!',
#  '그럼 직접흡연하는 난 얼마나 안좋겠니? 안그래? 보면 꼭... 지 생각만 하고.']

# %%
ket_df['감정'].unique()
# Out:
# array(['분노', '혐오', '중립', '놀람', '행복', '공포', '슬픔', 'ㅈ중립', '분ㄴ', '중림', nan,
#        'ㅍ', 'ㄴ중립', '분', '줄'], dtype=object)

# %%
ket_df[(ket_df['감정'] == 'ㅈ중립') | (ket_df['감정'] == '중림') | (ket_df['감정'] == '중림') | (ket_df['감정'] == 'ㄴ중립') | (ket_df['감정'] == '줄')] = '중립'
ket_df[(ket_df['감정'] == '분ㄴ') | (ket_df['감정'] == '분')] = '분노'
ket_df[ket_df['감정'] == 'ㅍ'] = '공포'

# %%
ket_df[ket_df['감정'].isna()] = '중립' # NaN을 없애버리면 맥락을 잃을 수 있음. 대신 중립으로 설정

# %%
ket_df['감정'].unique()
# Out:
# array(['분노', '혐오', '중립', '놀람', '행복', '공포', '슬픔'], dtype=object)

# %%
ket_df[ket_df['감정'] == '놀람']
# Out:
#       dialog #                        발화  감정
# 16         NaN           나? ... 나보고 하라고?  놀람
# 18         NaN           근데 왜... 나한테...?  놀람
# 48         NaN                    ... 오.  놀람
# 59         NaN                  ... 대리석?  놀람
# 105        NaN   요기잖아. 요기. 강 건너 윗동네도 몰라?  놀람
# ...        ...                       ...  ..
# 55464      NaN           ...그거 괜찮긴 한 거야?  놀람
# 55523      NaN               ……이 인형은 뭐야?  놀람
# 55585      NaN                   어? 정말요?  놀람
# 55587      NaN       혹시, 다들 은행 계좌없는 거예요?  놀람
# 55608      NaN                       정말?  놀람
#
# [4866 rows x 3 columns]

# %%
# 중립 (0), 부정 (1), 긍정 (2)
neg_emotion = ['분노', '혐오', '공포', '슬픔']
pos_emotion = ['행복']
neutral_emotion = ['놀람', '중립'] # 놀람은 긍정 또는 부정 한쪽으로 구분하기 어려운 관계로 중립에 포함

ket_df['감정'][ket_df['감정'].isin(neg_emotion)] = 1
ket_df['감정'][ket_df['감정'].isin(pos_emotion)] = 2
ket_df['감정'][ket_df['감정'].isin(neutral_emotion)] = 0

# %%
ket_df.iloc[0,0] = 'start' # 시작 지점 설정(이후 동일한 열에서 새로운 맥락이 시작되는 지점은 S로 표시되어 있음)

# %%
ket_df.head()
# Out:
#   dialog #                                            발화 감정
# 0    start          아 진짜! 사무실에서 피지 말라니깐! 간접흡연이 얼마나 안좋은데!  1
# 1      NaN  그럼 직접흡연하는 난 얼마나 안좋겠니? 안그래? 보면 꼭... 지 생각만 하고.  1
# 2      NaN                                       손님 왔어요.  0
# 3      NaN                                       손님? 누구?  0
# 4      NaN                                몰라요. 팀장님 친구래요.  0

# %%
columns = ['Q', 'A', 'label']
kor_emo_talk = pd.DataFrame(columns=columns)

for row in range(len(ket_df.index)):
  try:
    if row % 5000 == 0: print(f'row : {row}')
    if ket_df.iloc[row+1, 0] == 'S' : continue # NaN이 아닌 값(새로운 맥락의 대화)이 나오면 다음 순으로 넘기기
    sent_couple = pd.DataFrame([[ket_df.iloc[row, 1], ket_df.iloc[row+1, 1], ket_df.iloc[row+1, 2]]], columns=columns)
    kor_emo_talk = kor_emo_talk.append(sent_couple, ignore_index=True)
  except:
    print('done')
# Out:
# row : 0
# row : 5000
# row : 10000
# row : 15000
# row : 20000
# row : 25000
# row : 30000
# row : 35000
# row : 40000
# row : 45000
# row : 50000
# row : 55000
# done

# %%
kor_emo_talk.head()
# Out:
#                                               Q  ... label
# 0          아 진짜! 사무실에서 피지 말라니깐! 간접흡연이 얼마나 안좋은데!  ...     1
# 1  그럼 직접흡연하는 난 얼마나 안좋겠니? 안그래? 보면 꼭... 지 생각만 하고.  ...     0
# 2                                       손님 왔어요.  ...     0
# 3                                       손님? 누구?  ...     0
# 4                                몰라요. 팀장님 친구래요.  ...     0
#
# [5 rows x 3 columns]

# %%
kor_emo_talk[['Q', 'A']] = kor_emo_talk[['Q', 'A']].applymap(lambda x: x.replace(u'\xa0', u' '))

# %% [markdown]
# ### 1-4. 한국어 대화 데이터셋
#
# 출처 : [한국어 대화 데이터셋 - AI Hub](https://aihub.or.kr/opendata/keti-data/recognition-laguage/KETI-02-011)

# %%
# 응급 상황 대화
te_df = pd.read_excel('/content/drive/MyDrive/cd_ai/s4p/talk_emergency.xlsx')
te_df.head(25)
# Out:
#     num                                talk
# 0     1                     ﻿아빠가 숨을 잘 못쉬어요.
# 1     2                   그래요. 주소가 어떻게 되나요?
# 2     3                 한남동 123번지 고마스빌딩이예요.
# 3     4                 가슴에 통증이 있는지 물어봐줄래요?
# 4     5                있다고 해요. 이런경우는 처음이래요.
# 5     6  잠시만 기다려주세요. 도와줄 사람들을 금방 보내줄게요.알겠죠?
# 6     7                    알겠어요. 빨리 오셔야 되요.
# 7     8      지금 사람들이 가고 있어요. 아버지는 지금 깨어있나요?
# 8     9                                   네
# 9    10          전에도 이런적이 있었는지 아빠한테 물어봐줄래요?
# 10   11        아니요. 아직까지는 괜찮다고해요. 아직 깨어있어요.
# 11   12                   아버지 옆에 계속 있어주겠어요?
# 12   13                               알겠어요.
# 13   14              아빠가 깨어 계시는지 계속 지켜봐주세요.
# 14   15                            네 알겠어요.
# 15   16                        현관문은 열려 있나요?
# 16   17                                 아니요
# 17   18                  그럼 현관문을 열어줄 수 있나요?
# 18   19                             네 알겠어요.
# 19   20        금방 구급대원들이 도착할테니 잠시만 기다려주세요.
# 20    1                     우리 엄마가 아픈거 같아요.
# 21    2                      집 주소가 어떻게 되나요?
# 22    3             성남시 둔촌대로 69번길 전원주택 이예요.
# 23    4                        엄마 상태가 어떤가요?
# 24    5             가슴을 붙잡고 쓰러져서 일어나질 못하세요.

# %%
te_df.iloc[0,0] = 'start'
te_df.head()
# Out:
#      num                  talk
# 0  start       ﻿아빠가 숨을 잘 못쉬어요.
# 1      2     그래요. 주소가 어떻게 되나요?
# 2      3   한남동 123번지 고마스빌딩이예요.
# 3      4   가슴에 통증이 있는지 물어봐줄래요?
# 4      5  있다고 해요. 이런경우는 처음이래요.

# %%
columns = ['Q', 'A', 'label']
talk_emergency = pd.DataFrame(columns=columns)

for row in range(len(te_df.index)):
  try:
    if row % 1000 == 0: print(f'row : {row}')
    if te_df.iloc[row+1, 0] == 1 : continue
    sent_couple = pd.DataFrame([[te_df.iloc[row, 1], te_df.iloc[row+1, 1], 0]], columns=columns)
    talk_emergency = talk_emergency.append(sent_couple, ignore_index=True)
  except:
    print('done')
# Out:
# row : 0
# row : 1000
# row : 2000
# row : 3000
# row : 4000
# done

# %%
talk_emergency.head()
# Out:
#                       Q                                   A label
# 0       ﻿아빠가 숨을 잘 못쉬어요.                   그래요. 주소가 어떻게 되나요?     0
# 1     그래요. 주소가 어떻게 되나요?                 한남동 123번지 고마스빌딩이예요.     0
# 2   한남동 123번지 고마스빌딩이예요.                 가슴에 통증이 있는지 물어봐줄래요?     0
# 3   가슴에 통증이 있는지 물어봐줄래요?                있다고 해요. 이런경우는 처음이래요.     0
# 4  있다고 해요. 이런경우는 처음이래요.  잠시만 기다려주세요. 도와줄 사람들을 금방 보내줄게요.알겠죠?     0

# %%
# 일상(회사) 대화
to_df = pd.read_excel('/content/drive/MyDrive/cd_ai/s4p/talk_office.xlsx')
to_df.head()
# Out:
#    num     talk
# 0    1  ﻿좋은 아침.
# 1    2   안녕하세요.
# 2    1   좋은 아침.
# 3    2   반갑습니다.
# 4    1   좋은 아침.

# %%
columns = ['Q', 'A', 'label']
talk_office = pd.DataFrame(columns=columns)

for row in range(len(to_df.index)):
  try:
    if row % 1000 == 0: print(f'row : {row}')
    if row % 2 == 0:
      sent_couple = pd.DataFrame([[to_df.iloc[row, 1], to_df.iloc[row+1, 1], 0]], columns=columns)
      talk_office = talk_office.append(sent_couple, ignore_index=True)
  except:
    print('done')
# Out:
# row : 0
# row : 1000
# row : 2000

# %%
talk_office.head()
# Out:
#          Q             A label
# 0  ﻿좋은 아침.        안녕하세요.     0
# 1   좋은 아침.        반갑습니다.     0
# 2   좋은 아침.     좋은 아침이에요.     0
# 3   좋은 아침.  간밤에 별일 없으셨죠?     0
# 4   좋은 아침.      안녕하시렵니까?     0

# %% [markdown]
# ### 1-5. 데이터셋 합치기

# %%
df = pd.concat([cbdata_df, twitter_talk, kor_emo_talk, talk_emergency, talk_office], ignore_index=True)

# %%
df.shape
# Out:
# (74588, 3)

# %%
df.to_csv('data_total.csv', encoding='utf-8')

# %% [markdown]
# ## 2, 모델 학습시키기

# %%
# GPU 정보 
# !nvidia-smi
# Out:
# Wed Jan 12 05:26:35 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# KoGPT2-chatbot 소스 코드 복사
# !git clone --recurse-submodules https://github.com/seahahn/KoGPT2-chatbot.git
# Out:
# Cloning into 'KoGPT2-chatbot'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 103 (delta 8), reused 8 (delta 3), pack-reused 85
# Receiving objects: 100% (103/103), 115.98 KiB | 5.52 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# Submodule 'Chatbot_data' (https://github.com/haven-jeon/Chatbot_data.git) registered for path 'Chatbot_data'
# Cloning into '/content/KoGPT2-chatbot/Chatbot_data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 24 (delta 0), reused 3 (delta 0), pack-reused 20
# Submodule path 'Chatbot_data': checked out '235fac5aea3badab22743f7048afe936cf72f822'

# %%
# 폴더 이동
# %cd KoGPT2-chatbot
# Out:
# /content/KoGPT2-chatbot

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (1.1.5)
# Collecting pytorch_lightning==1.2.10
#   Downloading pytorch_lightning-1.2.10-py3-none-any.whl (841 kB)
#      |████████████████████████████████| 841 kB 5.0 MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (1.10.0+cu111)
# Collecting transformers==4.5.1
#   Downloading transformers-4.5.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 46.3 MB/s
# Collecting PyYAML!=5.4.*,>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 53.7 MB/s
# Requirement already satisfied: tensorboard!=2.5.0,>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (2.7.0)
# Collecting torchmetrics==0.2.0
#   Downloading torchmetrics-0.2.0-py3-none-any.whl (176 kB)
#      |████████████████████████████████| 176 kB 57.1 MB/s
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 51.5 MB/s
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (1.19.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (21.3)
# Collecting fsspec[http]>=0.8.1
#   Downloading fsspec-2022.1.0-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 59.9 MB/s
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r requirements.txt (line 4)) (2.23.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 39.8 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r requirements.txt (line 4)) (3.4.2)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 41.5 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r requirements.txt (line 4)) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r requirements.txt (line 4)) (4.10.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->-r requirements.txt (line 3)) (3.10.0.2)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 61.3 MB/s
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (0.37.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (57.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (1.35.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (3.17.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (1.43.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.5.1->-r requirements.txt (line 4)) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1->-r requirements.txt (line 4)) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1->-r requirements.txt (line 4)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1->-r requirements.txt (line 4)) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1->-r requirements.txt (line 4)) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->-r requirements.txt (line 1)) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 57.4 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (2.0.10)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (21.4.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (192 kB)
#      |████████████████████████████████| 192 kB 63.3 MB/s
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 54.9 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytorch_lightning==1.2.10->-r requirements.txt (line 2)) (3.0.6)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.5.1->-r requirements.txt (line 4)) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.5.1->-r requirements.txt (line 4)) (1.1.0)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=5fa24477220c933e7e7a4708eadf4bdebe61ac63364bc79d739a587289fdbd4b
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built future
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, fsspec, aiohttp, torchmetrics, tokenizers, sacremoses, PyYAML, future, transformers, pytorch-lightning
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.2.0 fsspec-2022.1.0 future-0.18.2 multidict-5.2.0 pytorch-lightning-1.2.10 sacremoses-0.0.47 tokenizers-0.10.3 torchmetrics-0.2.0 transformers-4.5.1 yarl-1.7.2

# %%
# 사전훈련된 KoGPT2를 챗봇 데이터로 파인튜닝
# !CUDA_VISIBLE_DEVICES=0 python train_torch.py --train --gpus 1 --max_epochs 100 --batch-size 128 --data_path '/content/data_total.csv'
# Out:
# INFO:root:Namespace(accelerator=None, accumulate_grad_batches=1, amp_backend='native', amp_level='O2', auto_lr_find=False, auto_scale_batch_size=False, auto_select_gpus=False, automatic_optimization=None, batch_size=128, benchmark=False, chat=False, check_val_every_n_epoch=1, checkpoint_callback=True, default_root_dir=None, deterministic=False, distributed_backend=None, enable_pl_optimizer=None, fast_dev_run=False, flush_logs_every_n_steps=100, gpus=1, gradient_clip_val=0, limit_predict_batches=1.0, limit_test_batches=1.0, limit_train_batches=1.0, limit_val_batches=1.0, log_every_n_steps=50, log_gpu_memory=None, logger=True, lr=5e-05, max_epochs=100, max_len=32, max_steps=None, min_epochs=None, min_steps=None, model_params='model_chp/model_-last.ckpt', move_metrics_to_cpu=False, multiple_trainloader_mode='max_size_cycle', num_nodes=1, num_processes=1, num_sanity_val_steps=2, overfit_batches=0.0, plugins=None, precision=32, prepare_data_per_node=True, process_position=0, profiler=None, progress_bar_refresh_rate=None, reload_dataloaders_every_epoch=False, replace_sampler_ddp=True, resume_from_checkpoint=None, sentiment='0', stochastic_weight_avg=False, sync_batchnorm=False, terminate_on_nan=False, tpu_cores=None, track_grad_norm=-1, train=True, truncated_bptt_steps=None, val_check_interval=1.0, warmup_ratio=0.1, weights_save_path=None, weights_summary='top')
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | kogpt2        | GPT2LMHeadModel  | 125 M
# 1 | loss_function | CrossEntropyLoss | 0
# ---------------------------------------------------
# 125 M     Trainable params
# 0         Non-trainable params
# 125 M     Total params
# 500.656   Total estimated model params size (MB)
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/distributed.py:68: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 4 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# Epoch 0:   0% 0/583 [00:00<?, ?it/s] INFO:root:contexts : 진짜요? 사실은 홍대 가고싶은데 제가 건대 가기엔 생활기록부가 안 좋아요. 걔네는 종합만 뽑던데 홍대는 교과도 뽑아요. 3호선은 자주 안 타시나요?
# INFO:root:toked ctx: ['대는', '▁교과', '도', '▁뽑아', '요.', '▁3', '호', '선은', '▁자주', '▁안', '▁타', '시나', '요', '?', '<unused1>', '▁0']
# INFO:root:response : 홍대 되시면 진짜 저희 동네랑 가깝네요! 와와! 근데 3호선은. 음. 그저 울지요.
# INFO:root:toked response : ['<sys>', '▁홍', '대', '▁되', '시', '면', '▁진짜', '▁저', '희', '▁동네', '랑', '▁가깝', '네', '요', '!', '▁와']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁홍', '대', '▁되', '시', '면', '▁진짜', '▁저', '희', '▁동네', '랑', '▁가깝', '네', '요', '!', '▁와']
# INFO:root:contexts : 왜 안자고?
# INFO:root:toked ctx: ['<usr>', '▁왜', '▁안', '자고', '?', '<unused1>', '▁0']
# INFO:root:response : 그거야 저도 모르죠
# INFO:root:toked response : ['<sys>', '▁그', '거', '야', '▁저', '도', '▁모르', '죠', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁그', '거', '야', '▁저', '도', '▁모르', '죠', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 0: 100% 583/583 [07:05<00:00,  1.37it/s, loss=23.5, v_num=1]Epoch 0, global step 582: train_loss reached 25.38632 (best 25.38632), saving model to "/content/KoGPT2-chatbot/model_chp/model_-epoch=00-train_loss=25.39.ckpt" as top 1
# tcmalloc: large alloc 1180934144 bytes == 0x55e1e0400000 @  0x7fc25bd00615 0x55e10d2524cc 0x55e10d33247a 0x55e10d258f0c 0x7fc230ad79e4 0x7fc230adfb14 0x7fc230ab4a60 0x7fc188292f55 0x7fc18828e88e 0x7fc188296235 0x7fc230ab4fae 0x7fc23022baa8 0x55e10d256098 0x55e10d2c94d9 0x55e10d2c3ced 0x55e10d256bda 0x55e10d2c4915 0x55e10d2c39ee 0x55e10d256bda 0x55e10d2c8d00 0x55e10d256afa 0x55e10d2c4915 0x55e10d2c39ee 0x55e10d256bda 0x55e10d2c4c0d 0x55e10d2c39ee 0x55e10d256bda 0x55e10d2c8d00 0x55e10d256afa 0x55e10d2c4c0d 0x55e10d256afa
# tcmalloc: large alloc 1476173824 bytes == 0x55e22aa14000 @  0x7fc25bd00615 0x55e10d2524cc 0x55e10d33247a 0x55e10d258f0c 0x7fc230ad79e4 0x7fc230adfb14 0x7fc230ab4a60 0x7fc188292f55 0x7fc18828e88e 0x7fc188296235 0x7fc230ab4fae 0x7fc23022baa8 0x55e10d256098 0x55e10d2c94d9 0x55e10d2c3ced 0x55e10d256bda 0x55e10d2c4915 0x55e10d2c39ee 0x55e10d256bda 0x55e10d2c8d00 0x55e10d256afa 0x55e10d2c4915 0x55e10d2c39ee 0x55e10d256bda 0x55e10d2c4c0d 0x55e10d2c39ee 0x55e10d256bda 0x55e10d2c8d00 0x55e10d256afa 0x55e10d2c4c0d 0x55e10d256afa
# tcmalloc: large alloc 1845223424 bytes == 0x55e2829de000 @  0x7fc25bd00615 0x55e10d2524cc 0x55e10d33247a 0x55e10d258f0c 0x7fc230ad79e4 0x7fc230adfb14 0x7fc230ab4a60 0x7fc188292f55 0x7fc18828e88e 0x7fc188296235 0x7fc230ab4fae 0x7fc23022baa8 0x55e10d256098 0x55e10d2c94d9 0x55e10d2c3ced 0x55e10d256bda 0x55e10d2c4915 0x55e10d2c39ee 0x55e10d256bda 0x55e10d2c8d00 0x55e10d256afa 0x55e10d2c4915 0x55e10d2c39ee 0x55e10d256bda 0x55e10d2c4c0d 0x55e10d2c39ee 0x55e10d256bda 0x55e10d2c8d00 0x55e10d256afa 0x55e10d2c4c0d 0x55e10d256afa
# tcmalloc: large alloc 1845223424 bytes == 0x55e2829de000 @  0x7fc25bd00615 0x55e10d2524cc 0x55e10d33247a 0x55e10d258f0c 0x7fc230ad79e4 0x7fc230adfb14 0x7fc230ab4a60 0x7fc188292f55 0x7fc18828e88e 0x7fc188296235 0x7fc230ab4fae 0x7fc23022baa8 0x55e10d256098 0x55e10d2c94d9 0x55e10d2c3ced 0x55e10d256bda 0x55e10d2c4915 0x55e10d2c39ee 0x55e10d256bda 0x55e10d2c8d00 0x55e10d256afa 0x55e10d2c4915 0x55e10d2c39ee 0x55e10d256bda 0x55e10d2c4c0d 0x55e10d2c39ee 0x55e10d256bda 0x55e10d2c8d00 0x55e10d256afa 0x55e10d2c4c0d 0x55e10d256afa
# Epoch 1:   0% 0/583 [00:00<?, ?it/s, loss=23.5, v_num=1]INFO:root:contexts : 광화문 지금 어디쪽이세요?
# INFO:root:contexts : 응
# INFO:root:toked ctx: ['<usr>', '▁응', '<unused1>', '▁0']
# INFO:root:toked ctx: ['<usr>', '▁광', '화문', '▁지금', '▁어디', '쪽', '이', '세', '요', '?', '<unused1>', '▁0']
# INFO:root:response : 내일도 도서부 일 해야 돼? 하긴, 하루만 더 나오면 방학이지만.
# INFO:root:response : 광화문 세종대왕쪽이요. 압사당하고 있어요.
# INFO:root:toked response : ['<sys>', '▁광', '화문', '▁세종대왕', '쪽', '이', '요.', '▁압', '사', '당하고', '▁있어', '요.', '▁', '</s>']
# INFO:root:toked response : ['<sys>', '▁내', '일', '도', '▁도서', '부', '▁일', '▁해야', '▁돼', '?', '▁하', '긴', ',', '▁하루', '만', '▁더', '▁나오면', '▁방학', '이지만', '.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁광', '화문', '▁세종대왕', '쪽', '이', '요.', '▁압', '사', '당하고', '▁있어', '요.', '▁', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁내', '일', '도', '▁도서', '부', '▁일', '▁해야', '▁돼', '?', '▁하', '긴', ',', '▁하루', '만', '▁더', '▁나오면', '▁방학', '이지만', '.', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 1: 100% 583/583 [07:05<00:00,  1.37it/s, loss=23.8, v_num=1]Epoch 1, global step 1165: train_loss reached 24.54045 (best 24.54045), saving model to "/content/KoGPT2-chatbot/model_chp/model_-epoch=01-train_loss=24.54.ckpt" as top 1
# tcmalloc: large alloc 1845223424 bytes == 0x55e2829de000 @  0x7fc25bd00615 0x55e10d2524cc 0x55e10d33247a 0x55e10d258f0c 0x7fc230ad79e4 0x7fc230adfb14 0x7fc230ab4a60 0x7fc188292f55 0x7fc18828e88e 0x7fc188296235 0x7fc230ab4fae 0x7fc23022baa8 0x55e10d256098 0x55e10d2c94d9 0x55e10d2c3ced 0x55e10d256bda 0x55e10d2c4915 0x55e10d2c39ee 0x55e10d256bda 0x55e10d2c8d00 0x55e10d256afa 0x55e10d2c4915 0x55e10d2c39ee 0x55e10d256bda 0x55e10d2c4c0d 0x55e10d2c39ee 0x55e10d256bda 0x55e10d2c8d00 0x55e10d256afa 0x55e10d2c4c0d 0x55e10d256afa
# Epoch 2:   0% 0/583 [00:00<?, ?it/s, loss=23.8, v_num=1]INFO:root:contexts : 조수씨 또 그런 소릴 해! 아빠는 그런 짓 안 해!
# INFO:root:toked ctx: ['<usr>', '▁조수', '씨', '▁또', '▁그런', '▁소', '릴', '▁해', '!', '▁아', '빠', '는', '▁그런', '▁짓', '▁안', '▁해', '!', '<unused1>', '▁0']
# INFO:root:response : 절대로 아닐 거라고 단언할 수 있어?
# INFO:root:toked response : ['<sys>', '▁절대로', '▁아닐', '▁거', '라고', '▁단', '언', '할', '▁수', '▁있어', '?', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁절대로', '▁아닐', '▁거', '라고', '▁단', '언', '할', '▁수', '▁있어', '?', '</s>']
# INFO:root:contexts : 하긴 그래. 지금이 제일일지도 모르지.
# INFO:root:toked ctx: ['<usr>', '▁하', '긴', '▁그래', '.', '▁지금', '이', '▁제일', '일', '지도', '▁모르', '지', '.', '<unused1>', '▁0']
# INFO:root:response : 웬일로 긍정적이네……?
# INFO:root:toked response : ['<sys>', '▁웬', '일로', '▁긍정', '적이', '네', '......', '?', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁웬', '일로', '▁긍정', '적이', '네', '......', '?', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 2: 100% 583/583 [07:05<00:00,  1.37it/s, loss=22.8, v_num=1]Epoch 2, global step 1748: train_loss reached 23.18029 (best 23.18029), saving model to "/content/KoGPT2-chatbot/model_chp/model_-epoch=02-train_loss=23.18.ckpt" as top 1
# Epoch 3:   0% 0/583 [00:00<?, ?it/s, loss=22.8, v_num=1]INFO:root:contexts : 그런 듣도보도 못한 방식으로 죽는다면 내가 두고두고 개그소재로 전해줄게. 자, 이거 병문안 선물.
# INFO:root:toked ctx: ['<usr>', '▁그런', '▁듣', '도', '보도', '▁못한', '▁방식으로', '▁죽는', '다면', '▁내가', '▁두고', '두고', '▁개', '그', '소', '재로', '▁전해', '줄', '게', '.', '▁자,', '▁이', '거', '▁병', '문', '안', '▁선물', '.', '<unused1>', '▁0']
# INFO:root:response : 아유, 뭘 이런 걸… 앗 딸기다! 와아, 빨리 먹자. 저기 선반에서 접시 좀 가져와.
# INFO:root:toked response : ['<sys>', '▁아']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁아']
# INFO:root:contexts : 초대형이요?.. 그럼 어느정도 스케일을 생각하고 계신지..
# INFO:root:toked ctx: ['<usr>', '▁초대', '형이', '요', '?', '..', '▁그럼', '▁어느', '정도', '▁스케', '일을', '▁생각하고', '▁계', '신', '지', '..', '<unused1>', '▁0']
# INFO:root:response : 세상에 저런 걸 하나 입이 떡 벌어질 정도로 사상최대규모의 그런 이벤트 말이야.
# INFO:root:toked response : ['<sys>', '▁세상에', '▁저', '런', '▁걸', '▁하나', '▁입이', '▁떡', '▁벌어', '질', '▁정도로', '▁사상', '최', '대']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁세상에', '▁저', '런', '▁걸', '▁하나', '▁입이', '▁떡', '▁벌어', '질', '▁정도로', '▁사상', '최', '대']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 3: 100% 583/583 [07:05<00:00,  1.37it/s, loss=23.1, v_num=1]Epoch 3, step 2331: train_loss was not in top 1
# Epoch 4:   0% 0/583 [00:00<?, ?it/s, loss=23.1, v_num=1]INFO:root:contexts : 안추워?
# INFO:root:toked ctx: ['<usr>', '▁안', '추', '워', '?', '<unused1>', '▁0']
# INFO:root:response : 조금...요...
# INFO:root:toked response : ['<sys>', '▁조금', '...', '요', '...', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁조금', '...', '요', '...', '</s>']
# INFO:root:contexts : 뮤지컬 왜 이렇게 비싸요? 영화 열 번 보는 가격이잖아요. 뮤지컬 좋긴 한데요. 그런 의미로 혁 오빠 영화 언제 찍죠? 내가 열 번 볼게요.
# INFO:root:toked ctx: ['▁의미로', '▁혁', '▁오빠', '▁영화', '▁언제', '▁찍', '죠', '?', '▁내가', '▁열', '▁번', '▁볼', '게', '요.', '<unused1>', '▁0']
# INFO:root:response : 나는 돈 없으니까 한 다섯 번만 볼게요. 미리 알려주기만 해요. 돈 좀 모아두게요.
# INFO:root:toked response : ['<sys>', '▁나는', '▁돈', '▁없으니', '까', '▁한', '▁다섯', '▁번', '만', '▁볼', '게', '요.', '▁미리', '▁알려', '주', '기만']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁나는', '▁돈', '▁없으니', '까', '▁한', '▁다섯', '▁번', '만', '▁볼', '게', '요.', '▁미리', '▁알려', '주', '기만']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 4: 100% 583/583 [07:05<00:00,  1.37it/s, loss=22.9, v_num=1]Epoch 4, global step 2914: train_loss reached 22.83545 (best 22.83545), saving model to "/content/KoGPT2-chatbot/model_chp/model_-epoch=04-train_loss=22.84.ckpt" as top 1
# Epoch 5:   0% 0/583 [00:00<?, ?it/s, loss=22.9, v_num=1]INFO:root:contexts : 가벼워졌다고 생각했는데
# INFO:root:toked ctx: ['<usr>', '▁가벼', '워', '졌다고', '▁생각', '했는데', '<unused1>', '▁1']
# INFO:root:response : 무거워도 괜찮아요.
# INFO:root:toked response : ['<sys>', '▁무거', '워', '도', '▁', '괜', '찮', '아', '요.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁무거', '워', '도', '▁', '괜', '찮', '아', '요.', '</s>']
# INFO:root:contexts : 네
# INFO:root:toked ctx: ['<usr>', '▁네', '<unused1>', '▁1']
# INFO:root:response : 나 포기 안할거야. 아니 이제부턴 진짜 잘해볼거야. 후회하지 않을만큼 최선을 다할거야.
# INFO:root:toked response : ['<sys>', '▁나', '▁포기', '▁안', '할', '거', '야', '.', '▁아니', '▁이제', '부', '턴', '▁진짜', '▁잘', '해볼', '거', '야', '.', '▁후회', '하지', '▁않을', '만큼', '▁최', '선을', '▁다', '할', '거', '야']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁나', '▁포기', '▁안', '할', '거', '야', '.', '▁아니', '▁이제', '부', '턴', '▁진짜', '▁잘', '해볼', '거', '야', '.', '▁후회', '하지', '▁않을', '만큼', '▁최', '선을', '▁다', '할', '거', '야']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 5: 100% 583/583 [07:05<00:00,  1.37it/s, loss=23.1, v_num=1]Epoch 5, global step 3497: train_loss reached 22.00763 (best 22.00763), saving model to "/content/KoGPT2-chatbot/model_chp/model_-epoch=05-train_loss=22.01.ckpt" as top 1
# Epoch 6:   0% 0/583 [00:00<?, ?it/s, loss=23.1, v_num=1]INFO:root:contexts : 여자친구의 이성친구가 고민이야.
# INFO:root:contexts : 그러니까 그 사람이 누군데?
# INFO:root:toked ctx: ['<usr>', '▁그러', '니까', '▁그', '▁사람이', '▁누', '군데', '?', '<unused1>', '▁0']
# INFO:root:toked ctx: ['<usr>', '▁여자', '친', '구의', '▁이성', '친', '구가', '▁고', '민이', '야', '.', '<unused1>', '▁2']
# INFO:root:response : 자...잠깐요. 그 전에 현..상금은 확실히 주나요?
# INFO:root:response : 만날 때 같이 만나세요.
# INFO:root:toked response : ['<sys>', '▁자', '...', '잠', '깐', '요.', '▁그', '▁전에', '▁현', '..', '상', '금은', '▁확실히', '▁주', '나', '요', '?', '</s>']
# INFO:root:toked response : ['<sys>', '▁만날', '▁때', '▁같이', '▁만나', '세', '요.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁만날', '▁때', '▁같이', '▁만나', '세', '요.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁자', '...', '잠', '깐', '요.', '▁그', '▁전에', '▁현', '..', '상', '금은', '▁확실히', '▁주', '나', '요', '?', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 6: 100% 583/583 [07:05<00:00,  1.37it/s, loss=23.1, v_num=1]Epoch 6, step 4080: train_loss was not in top 1
# Epoch 7:   0% 0/583 [00:00<?, ?it/s, loss=23.1, v_num=1]INFO:root:contexts : 병원에는 가 봤어요?
# INFO:root:toked ctx: ['<usr>', '▁병원', '에는', '▁가', '▁', '봤', '어', '요', '?', '<unused1>', '▁0']
# INFO:root:response : 알츠하이머... 진행 중이래. 더 심해지면... 입원 치료해야 해야 된다고… 휴우... 간신히 국가대표 코치까지 왔는데... 이게 뭔 일인지.
# INFO:root:toked response : ['<sys>', '▁알', '츠', '하이', '머', '...', '▁진행', '▁중이', '래', '.', '▁더', '▁심', '해지면', '...', '▁입원', '▁치료', '해야', '▁해야', '▁된다고', '...', '▁휴']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁알', '츠', '하이', '머', '...', '▁진행', '▁중이', '래', '.', '▁더', '▁심', '해지면', '...', '▁입원', '▁치료', '해야', '▁해야', '▁된다고', '...', '▁휴']
# INFO:root:contexts : 아니.
# INFO:root:toked ctx: ['<usr>', '▁아니', '.', '<unused1>', '▁0']
# INFO:root:response : 더 해, 그럼.
# INFO:root:toked response : ['<sys>', '▁더', '▁해,', '▁그럼', '.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁더', '▁해,', '▁그럼', '.', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 7: 100% 583/583 [07:05<00:00,  1.37it/s, loss=22.5, v_num=1]Epoch 7, step 4663: train_loss was not in top 1
# Epoch 8:   0% 0/583 [00:00<?, ?it/s, loss=22.5, v_num=1]INFO:root:contexts : 후
# INFO:root:toked ctx: ['<usr>', '▁후', '<unused1>', '▁1']
# INFO:root:response : 힘을 내세요.
# INFO:root:toked response : ['<sys>', '▁힘을', '▁내세', '요.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁힘을', '▁내세', '요.', '</s>']
# INFO:root:contexts : 자퇴하면 시간이 너무 널널하고 눈치 안 봐도 되고 사회 간접 체험할 경험 엄청 늘어나요. 시험 안 봐도 되고 부담감도 덜 가고 배우고 싶은 거 배울 시간이 넘쳐요. 잠시 요양하기에도 좋고요.
# INFO:root:toked ctx: ['▁가고', '▁배우고', '▁싶은', '▁거', '▁배울', '▁시간이', '▁넘쳐', '요.', '▁잠시', '▁요양', '하기', '에도', '▁좋고', '요.', '<unused1>', '▁0']
# INFO:root:response : 단점은 헤맬 수 있어요. 저도 그러는 중이에요. 목표가 중요해요. 늘 하는 말이지만 목표가 없다면 자퇴하지 마세요.
# INFO:root:toked response : ['<sys>', '▁단', '점은', '▁헤', '맬', '▁수', '▁있어', '요.', '▁저', '도', '▁그러', '는', '▁중', '이에', '요.', '▁목표']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁단', '점은', '▁헤', '맬', '▁수', '▁있어', '요.', '▁저', '도', '▁그러', '는', '▁중', '이에', '요.', '▁목표']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 8: 100% 583/583 [07:05<00:00,  1.37it/s, loss=22.9, v_num=1]Epoch 8, step 5246: train_loss was not in top 1
# Epoch 9:   0% 0/583 [00:00<?, ?it/s, loss=22.9, v_num=1]INFO:root:contexts : 젊은 층한테는 책이나 디비디나 다 같은 의미니까요. 디지털 아날로그 개념 구분이 없어지고 있잖아요.
# INFO:root:toked ctx: ['<usr>', '▁젊은', '▁층', '한', '테는', '▁책', '이나', '▁디', '비', '디나', '▁다', '▁같은', '▁의미', '니까', '요.', '▁디지털', '▁아날', '로그', '▁개념', '▁구분이', '▁없어지고', '▁있', '잖', '아', '요.', '<unused1>', '▁0']
# INFO:root:response : 알아서 해라. 니가 나보단 잘 알겠지.
# INFO:root:toked response : ['<sys>', '▁알아서', '▁해', '라.', '▁니']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁알아서', '▁해', '라.', '▁니']
# INFO:root:contexts : 거짓말하신 건..뭐 그럴 수도 있다고 생각해요. 근데 아까 그 상황에서 따님 모습을 보고..좀..마음이 혼란스럽네요.
# INFO:root:toked ctx: ['▁상황에서', '▁따', '님', '▁모습을', '▁보고', '..', '좀', '..', '마', '음이', '▁혼란', '스럽', '네', '요.', '<unused1>', '▁0']
# INFO:root:response : 하..우리 이러지 말고 지금 좀 만나죠.
# INFO:root:toked response : ['<sys>', '▁하', '..', '우리', '▁이러', '지', '▁말고', '▁지금', '▁좀', '▁만나', '죠', '.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁하', '..', '우리', '▁이러', '지', '▁말고', '▁지금', '▁좀', '▁만나', '죠', '.', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 9: 100% 583/583 [07:05<00:00,  1.37it/s, loss=22.7, v_num=1]Epoch 9, global step 5829: train_loss reached 21.89107 (best 21.89107), saving model to "/content/KoGPT2-chatbot/model_chp/model_-epoch=09-train_loss=21.89.ckpt" as top 1
# Epoch 10:   0% 0/583 [00:00<?, ?it/s, loss=22.7, v_num=1]INFO:root:contexts : 오늘도 너무 바빠.
# INFO:root:toked ctx: ['<usr>', '▁오늘', '도', '▁너무', '▁바', '빠', '.', '<unused1>', '▁0']
# INFO:root:response : 업무량이 많으신것 같네요.
# INFO:root:toked response : ['<sys>', '▁업무', '량이', '▁많', '으', '신', '것', '▁같', '네', '요.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁업무', '량이', '▁많', '으', '신', '것', '▁같', '네', '요.', '</s>']
# INFO:root:contexts : 네, 집 문을 두드리고 있어요.
# INFO:root:toked ctx: ['<usr>', '▁네', ',', '▁집', '▁문을', '▁두드', '리고', '▁있어', '요.', '▁', '<unused1>', '▁0']
# INFO:root:response : 집에 혼자 계신가요?
# INFO:root:toked response : ['<sys>', '▁집에', '▁혼자', '▁계', '신', '가', '요', '?', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁집에', '▁혼자', '▁계', '신', '가', '요', '?', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 10: 100% 583/583 [07:05<00:00,  1.37it/s, loss=22.4, v_num=1]Epoch 10, step 6412: train_loss was not in top 1
# Epoch 11:   0% 0/583 [00:00<?, ?it/s, loss=22.4, v_num=1]INFO:root:contexts : 맞아요. 지금 에어컨 빵빵 틀어져있는 카페라서 다행이에요.
# INFO:root:contexts : 상관없어!
# INFO:root:toked ctx: ['<usr>', '▁상관', '없', '어', '!', '<unused1>', '▁1']
# INFO:root:toked ctx: ['<usr>', '▁맞아', '요.', '▁지금', '▁에어', '컨', '▁빵', '빵', '▁틀', '어져', '있는', '▁카', '페라', '서', '▁다행', '이에', '요.', '<unused1>', '▁0']
# INFO:root:response : 내 눈 보고 얘기해요! 엄마 무덤에 대고 맹세해요. 다신 안 해요.
# INFO:root:response : 카페요? 나도 카페 가고 싶어요. 뭐 먹어요?
# INFO:root:toked response : ['<sys>', '▁카페', '요', '?', '▁나도', '▁카페', '▁가고', '▁싶어', '요.', '▁뭐', '▁먹어', '요', '?']
# INFO:root:toked response : ['<sys>', '▁내', '▁눈', '▁보고', '▁얘', '기', '해', '요', '!', '▁엄마', '▁무덤에', '▁대고', '▁맹세', '해', '요.', '▁다', '신', '▁안', '▁해', '요.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁카페', '요', '?', '▁나도', '▁카페', '▁가고', '▁싶어', '요.', '▁뭐', '▁먹어', '요', '?']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁내', '▁눈', '▁보고', '▁얘', '기', '해', '요', '!', '▁엄마', '▁무덤에', '▁대고', '▁맹세', '해', '요.', '▁다', '신', '▁안', '▁해', '요.', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 11: 100% 583/583 [07:05<00:00,  1.37it/s, loss=21.9, v_num=1]Epoch 11, step 6995: train_loss was not in top 1
# Epoch 12:   0% 0/583 [00:00<?, ?it/s, loss=21.9, v_num=1]INFO:root:contexts : 모르니까 물어보지.
# INFO:root:toked ctx: ['<usr>', '▁모르', '니까', '▁물어', '보지', '.', '<unused1>', '▁1']
# INFO:root:response : 나쁜 놈.
# INFO:root:toked response : ['<sys>', '▁나쁜', '▁놈', '.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁나쁜', '▁놈', '.', '</s>']
# INFO:root:contexts : 차 쓰시려고 그러십니까, 형수님?
# INFO:root:toked ctx: ['<usr>', '▁차', '▁쓰', '시', '려고', '▁그러', '십', '니까', ',', '▁형', '수', '님', '?', '▁', '<unused1>', '▁0']
# INFO:root:response : 아니 그냥.... 사무실에 놔두고 온 게 있어서.... 차 키 가지고 있어요?
# INFO:root:toked response : ['<sys>', '▁아니', '▁그냥', '....', '▁사무', '실에', '▁', '놔', '두고', '▁온', '▁게', '▁있어서', '....', '▁차', '▁키', '▁가지고']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁아니', '▁그냥', '....', '▁사무', '실에', '▁', '놔', '두고', '▁온', '▁게', '▁있어서', '....', '▁차', '▁키', '▁가지고']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 12: 100% 583/583 [07:05<00:00,  1.37it/s, loss=21.6, v_num=1]Epoch 12, step 7578: train_loss was not in top 1
# Epoch 13:   0% 0/583 [00:00<?, ?it/s, loss=21.6, v_num=1]INFO:root:contexts : ……저도, 진실된 걸 원했어요.
# INFO:root:toked ctx: ['<usr>', '▁......', '저', '도,', '▁진실', '된', '▁걸', '▁원', '했', '어', '요.', '<unused1>', '▁0']
# INFO:root:response : 다 듣고 있었냐…… ……좀 잊어 주라.
# INFO:root:toked response : ['<sys>', '▁다', '▁듣고', '▁있었', '냐', '......', '▁......', '좀', '▁잊', '어', '▁주', '라.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁다', '▁듣고', '▁있었', '냐', '......', '▁......', '좀', '▁잊', '어', '▁주', '라.', '</s>']
# INFO:root:contexts : 아무튼 너는 좀 더 바깥 활동을 하는 게 좋다고 봐. 비타민C랬나? 그런 게 만들어진대.
# INFO:root:toked ctx: ['<usr>', '▁아무', '튼', '▁너', '는', '▁좀', '▁더', '▁바깥', '▁활동을', '▁하는', '▁게', '▁좋다고', '▁봐', '.', '▁비타민', 'C', '랬', '나', '?', '▁그런', '▁게', '▁만들어진', '대', '.', '<unused1>', '▁0']
# INFO:root:response : 그게 아니라 비타민 D겠지. 비타민 C를 만들어 내다니 네가 무슨 레몬이냐. 인체에서는 비타민 C가 생성되지 않거든?
# INFO:root:toked response : ['<sys>', '▁그', '게', '▁아니라', '▁비타민', '▁D']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁그', '게', '▁아니라', '▁비타민', '▁D']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 13: 100% 583/583 [07:05<00:00,  1.37it/s, loss=21.4, v_num=1]Epoch 13, global step 8161: train_loss reached 21.13873 (best 21.13873), saving model to "/content/KoGPT2-chatbot/model_chp/model_-epoch=13-train_loss=21.14.ckpt" as top 1
# Epoch 14:   0% 0/583 [00:00<?, ?it/s, loss=21.4, v_num=1]INFO:root:contexts : 와, 미쳤네요. 맞다. 월요일 날 다 본 반이 미온이 반이죠.
# INFO:root:toked ctx: ['<usr>', '▁와', ',', '▁미쳤', '네', '요.', '▁맞', '다.', '▁월', '요일', '▁날', '▁다', '▁본', '▁반', '이', '▁미', '온', '이', '▁반', '이', '죠', '.', '▁', '<unused1>', '▁0']
# INFO:root:response : 맞아요. 우리 월요일에 다 봤어요. 이제 다음 주 화요일에 하나만 남았어요. 심지어 월요일에 수행 평가 두 시간 보고 3교시 체력 검사 했어요.
# INFO:root:toked response : ['<sys>', '▁맞아', '요.', '▁우리', '▁월', '요', '일에']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁맞아', '요.', '▁우리', '▁월', '요', '일에']
# INFO:root:contexts : 쉰지 10분도 안 지났거든.
# INFO:root:toked ctx: ['<usr>', '▁쉰', '지', '▁10', '분', '도', '▁안', '▁지', '났', '거든', '.', '<unused1>', '▁0']
# INFO:root:response : 쉬기 싫음 혼자 공부하던지.
# INFO:root:toked response : ['<sys>', '▁쉬', '기', '▁싫', '음', '▁혼자', '▁공부', '하던', '지', '.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁쉬', '기', '▁싫', '음', '▁혼자', '▁공부', '하던', '지', '.', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 14: 100% 583/583 [07:05<00:00,  1.37it/s, loss=21.2, v_num=1]Epoch 14, step 8744: train_loss was not in top 1
# Epoch 15:   0% 0/583 [00:00<?, ?it/s, loss=21.2, v_num=1]INFO:root:contexts : 죄송합니다..! 결혼하신 게 아직 적응이 안 되서..
# INFO:root:toked ctx: ['<usr>', '▁죄', '송', '합니다.', '.', '!', '▁결혼', '하신', '▁게', '▁아직', '▁적응', '이', '▁안', '▁되', '서', '..', '<unused1>', '▁0']
# INFO:root:response : 무슨 일이야?
# INFO:root:toked response : ['<sys>', '▁무슨', '▁일이', '야', '?', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁무슨', '▁일이', '야', '?', '</s>']
# INFO:root:contexts : 하기 싫을 때 억지로 하면 안 돼요.
# INFO:root:toked ctx: ['<usr>', '▁하기', '▁싫', '을', '▁때', '▁억지로', '▁하면', '▁안', '▁돼', '요.', '<unused1>', '▁0']
# INFO:root:response : 안 가고 지금 밥 먹고 후식으로 초콜릿 먹는 중이에요.. 열덕이는 오늘도 맛있는 거 먹었더라 부럽게요.
# INFO:root:toked response : ['<sys>', '▁안', '▁가고', '▁지금', '▁밥', '▁먹고', '▁후', '식으로', '▁초콜릿', '▁먹는', '▁중', '이에', '요', '..', '▁열', '덕', '이는', '▁오늘', '도', '▁맛있는']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁안', '▁가고', '▁지금', '▁밥', '▁먹고', '▁후', '식으로', '▁초콜릿', '▁먹는', '▁중', '이에', '요', '..', '▁열', '덕', '이는', '▁오늘', '도', '▁맛있는']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 15: 100% 583/583 [07:05<00:00,  1.37it/s, loss=21.5, v_num=1]Epoch 15, step 9327: train_loss was not in top 1
# Epoch 16:   0% 0/583 [00:00<?, ?it/s, loss=21.5, v_num=1]INFO:root:contexts : 어때? 방은 맘에 드나?
# INFO:root:toked ctx: ['<usr>', '▁어', '때', '?', '▁방', '은', '▁맘', '에', '▁드나', '?', '<unused1>', '▁0']
# INFO:root:response : 예.
# INFO:root:toked response : ['<sys>', '▁예', '.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁예', '.', '</s>']
# INFO:root:contexts : 사랑 없이도 잘 살았는데
# INFO:root:toked ctx: ['<usr>', '▁사랑', '▁없이도', '▁잘', '▁살았', '는데', '<unused1>', '▁1']
# INFO:root:response : 사랑 없이도 잘 살았던 자신으로 돌아가봐요
# INFO:root:toked response : ['<sys>', '▁사랑', '▁없이도', '▁잘', '▁살았던', '▁자신', '으로', '▁돌아가', '봐', '요', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁사랑', '▁없이도', '▁잘', '▁살았던', '▁자신', '으로', '▁돌아가', '봐', '요', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 16: 100% 583/583 [07:05<00:00,  1.37it/s, loss=21.8, v_num=1]Epoch 16, step 9910: train_loss was not in top 1
# Epoch 17:   0% 0/583 [00:00<?, ?it/s, loss=21.8, v_num=1]INFO:root:contexts : 웃겨. 진짜. 지가 언제부터 애 챙겼다구... 천하의 난봉꾼. 바람둥이...
# INFO:root:toked ctx: ['<usr>', '▁웃', '겨', '.', '▁진짜', '.', '▁지가', '▁언제부터', '▁애', '▁챙', '겼', '다', '구', '...', '▁천하의', '▁난', '봉', '꾼', '.', '▁바람', '둥이', '...', '▁', '<unused1>', '▁0']
# INFO:root:response : 아이는 남편 분. 집에 같이 있다고 했죠?
# INFO:root:toked response : ['<sys>', '▁아이는', '▁남편', '▁분', '.', '▁집에', '▁같이']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁아이는', '▁남편', '▁분', '.', '▁집에', '▁같이']
# INFO:root:contexts : 아 진짜! 사무실에서 피지 말라니깐! 간접흡연이 얼마나 안좋은데!
# INFO:root:toked ctx: ['<usr>', '▁아', '▁진짜', '!', '▁사무', '실에서', '▁피지', '▁말라', '니', '깐', '!', '▁간접', '흡', '연이', '▁얼마나', '▁안', '좋은', '데', '!', '<unused1>', '▁1']
# INFO:root:response : 그럼 직접흡연하는 난 얼마나 안좋겠니? 안그래? 보면 꼭... 지 생각만 하고.
# INFO:root:toked response : ['<sys>', '▁그럼', '▁직접', '흡', '연', '하는', '▁난', '▁얼마나', '▁안', '좋', '겠']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁그럼', '▁직접', '흡', '연', '하는', '▁난', '▁얼마나', '▁안', '좋', '겠']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 17: 100% 583/583 [07:05<00:00,  1.37it/s, loss=21, v_num=1]  Epoch 17, step 10493: train_loss was not in top 1
# Epoch 18:   0% 0/583 [00:00<?, ?it/s, loss=21, v_num=1]INFO:root:contexts : 일 다 끝났어?
# INFO:root:toked ctx: ['<usr>', '▁일', '▁다', '▁끝났', '어', '?', '<unused1>', '▁0']
# INFO:root:response : 어.
# INFO:root:contexts : 베이징 중앙빌딩 1층이예요. 8명의 남성이 총을 들고 들어왔어요.
# INFO:root:toked response : ['<sys>', '▁어', '.', '▁', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁어', '.', '▁', '</s>']
# INFO:root:toked ctx: ['<usr>', '▁베이징', '▁중앙', '빌딩', '▁1', '층이', '예', '요.', '▁8', '명의', '▁남성이', '▁총을', '▁들고', '▁들어왔', '어', '요.', '<unused1>', '▁0']
# INFO:root:response : 다치신 분은 없으신가요?
# INFO:root:toked response : ['<sys>', '▁다', '치', '신', '▁분', '은', '▁없', '으', '신', '가', '요', '?', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁다', '치', '신', '▁분', '은', '▁없', '으', '신', '가', '요', '?', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 18: 100% 583/583 [07:05<00:00,  1.37it/s, loss=20.7, v_num=1]Epoch 18, global step 11076: train_loss reached 19.52107 (best 19.52107), saving model to "/content/KoGPT2-chatbot/model_chp/model_-epoch=18-train_loss=19.52.ckpt" as top 1
# Epoch 19:   0% 0/583 [00:00<?, ?it/s, loss=20.7, v_num=1]INFO:root:contexts : 프리마켓 구경가야지
# INFO:root:toked ctx: ['<usr>', '▁프리', '마켓', '▁구경', '가야', '지', '<unused1>', '▁0']
# INFO:root:response : 득템해오세요.
# INFO:root:toked response : ['<sys>', '▁득', '템', '해오', '세', '요.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁득', '템', '해오', '세', '요.', '</s>']
# INFO:root:contexts : 어떻게 알아?
# INFO:root:toked ctx: ['<usr>', '▁어떻게', '▁알아', '?', '<unused1>', '▁0']
# INFO:root:response : 가시기 직전에 한번 오실 거 같더라구요.
# INFO:root:toked response : ['<sys>', '▁가', '시기', '▁직전에', '▁한번', '▁오', '실', '▁거', '▁같', '더', '라', '구', '요.', '▁', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁가', '시기', '▁직전에', '▁한번', '▁오', '실', '▁거', '▁같', '더', '라', '구', '요.', '▁', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 19: 100% 583/583 [07:06<00:00,  1.37it/s, loss=20.5, v_num=1]Epoch 19, step 11659: train_loss was not in top 1
# Epoch 20:   0% 0/583 [00:00<?, ?it/s, loss=20.5, v_num=1]INFO:root:contexts : 진짜로? 고마워.
# INFO:root:toked ctx: ['<usr>', '▁진짜', '로', '?', '▁고', '마', '워', '.', '<unused1>', '▁2']
# INFO:root:response : 징그러.
# INFO:root:toked response : ['<sys>', '▁징', '그러', '.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁징', '그러', '.', '</s>']
# INFO:root:contexts : 홍대 디저트 연구소에요.
# INFO:root:toked ctx: ['<usr>', '▁홍', '대', '▁디', '저', '트', '▁연구', '소에', '요.', '<unused1>', '▁0']
# INFO:root:response : 수능만 끝나면 바로 달려가야겠어요!!
# INFO:root:toked response : ['<sys>', '▁수', '능', '만', '▁끝나면', '▁바로', '▁달려', '가야', '겠', '어', '요', '!', '!', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁수', '능', '만', '▁끝나면', '▁바로', '▁달려', '가야', '겠', '어', '요', '!', '!', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# ...
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁사랑', '▁앞에', '선', '▁진실', '된', '▁모습이', '▁좋아', '요.', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 86: 100% 583/583 [07:05<00:00,  1.37it/s, loss=20.1, v_num=1]Epoch 86, step 50720: train_loss was not in top 1
# Epoch 87:   0% 0/583 [00:00<?, ?it/s, loss=20.1, v_num=1]INFO:root:contexts : 시간을 조금 앞당길 수 있을까요?
# INFO:root:toked ctx: ['<usr>', '▁시간을', '▁조금', '▁앞당', '길', '▁수', '▁있을', '까', '요', '?', '<unused1>', '▁0']
# INFO:root:response : 아, 다른 강습이 잡혀 있어서 일정 변경은 힘들어요.
# INFO:root:toked response : ['<sys>', '▁아', ',', '▁다른', '▁강습', '이', '▁잡혀', '▁있어서', '▁일정', '▁변경', '은', '▁힘들어', '요.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁아', ',', '▁다른', '▁강습', '이', '▁잡혀', '▁있어서', '▁일정', '▁변경', '은', '▁힘들어', '요.', '</s>']
# INFO:root:contexts : 싫은가 봐? 싫음 말고. 공부하자. 이거 풀다 말았어.
# INFO:root:toked ctx: ['<usr>', '▁싫', '은', '가', '▁봐', '?', '▁싫', '음', '▁말고', '.', '▁공부', '하자', '.', '▁이', '거', '▁풀', '다', '▁말', '았', '어', '.', '<unused1>', '▁1']
# INFO:root:response : 오빠..빌려주세요.
# INFO:root:toked response : ['<sys>', '▁오빠', '..', '빌', '려', '주', '세', '요.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁오빠', '..', '빌', '려', '주', '세', '요.', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 87: 100% 583/583 [07:05<00:00,  1.37it/s, loss=19.9, v_num=1]Epoch 87, step 51303: train_loss was not in top 1
# Epoch 88:   0% 0/583 [00:00<?, ?it/s, loss=19.9, v_num=1]INFO:root:contexts : 하아…
# INFO:root:toked ctx: ['<usr>', '▁하', '아', '...', '<unused1>', '▁0']
# INFO:root:response : 별일이네..
# INFO:root:toked response : ['<sys>', '▁별', '일이', '네', '..', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁별', '일이', '네', '..', '</s>']
# INFO:root:contexts : 오늘 좀 집중력이 떨어지네.
# INFO:root:toked ctx: ['<usr>', '▁오늘', '▁좀', '▁집중', '력이', '▁떨어', '지', '네.', '<unused1>', '▁0']
# INFO:root:response : 잠깐 스트레칭 하며 쉬는 건 어떠세요?
# INFO:root:toked response : ['<sys>', '▁잠깐', '▁스트', '레', '칭', '▁하며', '▁쉬', '는', '▁건', '▁어떠', '세', '요', '?', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁잠깐', '▁스트', '레', '칭', '▁하며', '▁쉬', '는', '▁건', '▁어떠', '세', '요', '?', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 88: 100% 583/583 [07:05<00:00,  1.37it/s, loss=19.9, v_num=1]Epoch 88, step 51886: train_loss was not in top 1
# Epoch 89:   0% 0/583 [00:00<?, ?it/s, loss=19.9, v_num=1]INFO:root:contexts : 뭐야? 뭐야? 오늘도 보자는거야, 지금?
# INFO:root:toked ctx: ['<usr>', '▁뭐', '야', '?', '▁뭐', '야', '?', '▁오늘', '도', '▁보', '자는', '거', '야,', '▁지금', '?', '<unused1>', '▁0']
# INFO:root:response : 심심한가봐...
# INFO:root:contexts : 혼나진 않겠지. 잔소리나 비꼬는 말을 듣거나 형식적으로 불려지는 것 정도로 끝날 거야.
# INFO:root:toked response : ['<sys>', '▁심', '심한', '가', '봐', '...', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁심', '심한', '가', '봐', '...', '</s>']
# INFO:root:toked ctx: ['<usr>', '▁혼', '나', '진', '▁않겠', '지', '.', '▁잔', '소리', '나', '▁비', '꼬', '는', '▁말을', '▁듣', '거나', '▁형식', '적으로', '▁불려', '지는', '▁것', '▁정도로', '▁끝날', '▁거', '야', '.', '<unused1>', '▁0']
# INFO:root:response : 그게 혼나는 거잖아요..
# INFO:root:toked response : ['<sys>', '▁그', '게', '▁혼']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁그', '게', '▁혼']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 89: 100% 583/583 [07:05<00:00,  1.37it/s, loss=19.7, v_num=1]Epoch 89, step 52469: train_loss was not in top 1
# Epoch 90:   0% 0/583 [00:00<?, ?it/s, loss=19.7, v_num=1]INFO:root:contexts : 동생한테 민증 발급하라고 편지 왔어요. 님들아 00년생 이제 민증 생겨요!
# INFO:root:toked ctx: ['<usr>', '▁동생', '한테', '▁민', '증', '▁발급', '하라고', '▁편지', '▁왔', '어', '요.', '▁님', '들', '아', '▁', '00년', '생', '▁이제', '▁민', '증', '▁생겨', '요', '!', '▁', '<unused1>', '▁0']
# INFO:root:response : 내 동생은 12월생이네요.
# INFO:root:toked response : ['<sys>', '▁내', '▁동생', '은', '▁12월', '생이']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁내', '▁동생', '은', '▁12월', '생이']
# INFO:root:contexts : 여장하고 다닌다는 건 아직 확인 못했습니다. 틈틈이 유학원을 돌아다니며 유학관련 자료들을 모으고 있구요. 도서관에서 범죄관련 서적을 읽는 등 최근 일어난 연쇄살인에 관심이 많아 보입니다.
# INFO:root:toked ctx: ['▁범죄', '관련', '▁서적을', '▁읽는', '▁등', '▁최근', '▁일어난', '▁연쇄', '살', '인에', '▁관심이', '▁많아', '▁보', '입니다.', '<unused1>', '▁0']
# INFO:root:response : 이유가 뭐야?
# INFO:root:toked response : ['<sys>', '▁이유가', '▁뭐', '야', '?', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁이유가', '▁뭐', '야', '?', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 90: 100% 583/583 [07:05<00:00,  1.37it/s, loss=19.9, v_num=1]Epoch 90, step 53052: train_loss was not in top 1
# Epoch 91:   0% 0/583 [00:00<?, ?it/s, loss=19.9, v_num=1]INFO:root:contexts : 나 점점 괴물이 되고 있어
# INFO:root:toked ctx: ['<usr>', '▁나', '▁점점', '▁괴', '물이', '▁되고', '▁있어', '<unused1>', '▁0']
# INFO:root:response : 그렇지 않아요.
# INFO:root:toked response : ['<sys>', '▁그렇지', '▁않아', '요.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁그렇지', '▁않아', '요.', '</s>']
# INFO:root:contexts : 그러셨어요? 죄송해요. 그게요. 걔가 제가 변호사님이랑 사귀는 거. 알구. 두 분이 그렇게 가버리니까. 오해를 해 갖구요. 변호사님이 저 갖구노는 거라구. 막~ 의심하더니요. 그렇게 사고를 쳐 버린 거에요.
# INFO:root:toked ctx: ['.', '▁막', '~', '▁의심', '하', '더니', '요.', '▁그렇게', '▁사고를', '▁쳐', '▁버린', '▁거', '에', '요.', '<unused1>', '▁0']
# INFO:root:response : 그랬군요.
# INFO:root:toked response : ['<sys>', '▁그랬', '군', '요.', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁그랬', '군', '요.', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 91: 100% 583/583 [07:05<00:00,  1.37it/s, loss=19.4, v_num=1]Epoch 91, step 53635: train_loss was not in top 1
# Epoch 92:   0% 0/583 [00:00<?, ?it/s, loss=19.4, v_num=1]INFO:root:contexts : 그녀도 나를 좋아하는 줄 알았는데 아닌가봐.
# INFO:root:contexts : 뭐?!!
# INFO:root:toked ctx: ['<usr>', '▁뭐', '?', '!', '!', '<unused1>', '▁0']
# INFO:root:toked ctx: ['<usr>', '▁그녀', '도', '▁나를', '▁좋아하는', '▁줄', '▁알', '았는데', '▁아닌가', '봐', '.', '<unused1>', '▁2']
# INFO:root:response : 하..어..어떡하죠?
# INFO:root:response : 가끔 헷갈리게 하는 사람이 있어요.
# INFO:root:toked response : ['<sys>', '▁가끔', '▁', '헷', '갈', '리게', '▁하는', '▁사람이', '▁있어', '요.', '</s>']
# INFO:root:toked response : ['<sys>', '▁하', '..', '어', '..', '어', '떡', '하', '죠', '?', '▁', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁하', '..', '어', '..', '어', '떡', '하', '죠', '?', '▁', '</s>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁가끔', '▁', '헷', '갈', '리게', '▁하는', '▁사람이', '▁있어', '요.', '</s>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 92: 100% 583/583 [07:05<00:00,  1.37it/s, loss=19.9, v_num=1]Epoch 92, step 54218: train_loss was not in top 1
# Epoch 93:   0% 0/583 [00:00<?, ?it/s, loss=19.9, v_num=1]INFO:root:contexts : 야! 일 년 넘게 알고 지낸 사람을 홀랑 까먹어 버리는 큰 컨망증이 어디 있어?
# INFO:root:contexts : 반영이 너무 커요! 너무 귀찮아요. 에세이 두 개쓰고 토익 스피킹도 보고, 하지만 아무것도 시작하기 싫어요.
# INFO:root:toked ctx: ['<usr>', '▁야', '!', '▁일', '▁년', '▁넘게', '▁알고', '▁지낸', '▁사람을', '▁홀', '랑', '▁까', '먹', '어', '▁버리는', '▁큰', '▁컨', '망', '증이', '▁어디', '▁있어', '?', '<unused1>', '▁0']
# INFO:root:response : 일 년? 저랑 일 년이나 알고 지냈다고 했습니까?
# INFO:root:toked response : ['<sys>', '▁일', '▁년', '?', '▁저', '랑', '▁일', '▁년']
# INFO:root:toked ctx: ['<usr>', '▁반영', '이', '▁너무', '▁커', '요', '!', '▁너무', '▁귀', '찮', '아', '요.', '▁에', '세이', '▁두', '▁개', '쓰고', '▁토', '익', '▁스피', '킹', '도', '▁보고,', '▁하지만', '▁아무것도', '▁시작', '하기', '▁싫어', '요.', '<unused1>', '▁0']
# INFO:root:response : 언제까진데요?
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '▁일', '▁년', '?', '▁저', '랑', '▁일', '▁년']
# INFO:root:toked response : ['<sys>']
# INFO:root:labels ['<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>', '<unused0>']
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# train_torch.py:184: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   return torch.LongTensor(data), torch.LongTensor(mask), torch.LongTensor(label)
# Epoch 93:  69% 400/583 [04:52<02:13,  1.37it/s, loss=20.1, v_num=1]/usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/distributed.py:68: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   warnings.warn(*args, **kwargs)
# Saving latest checkpoint...
# Epoch 93, step 54631: train_loss was not in top 1
# Epoch 93:  69% 400/583 [05:11<02:22,  1.28it/s, loss=20.1, v_num=1]
# INFO:root:best model path /content/KoGPT2-chatbot/model_chp/model_-epoch=36-train_loss=16.83.ckpt

# %%
# 대화 테스트, `quit`를 입력하면 대화 종료
# 미리 학습해둔 가중치를 불러옴
# 만약 새로 학습한 가중치를 불러오려면 ckpt 파일의 경로를 해당 파일 경로로 지정해주면 됨
# !CUDA_VISIBLE_DEVICES=0 python train_torch.py --gpus 1 --model_params '/content/drive/MyDrive/cd_ai/s4p/model_best.ckpt' --chat
# Out:
# INFO:root:Namespace(accelerator=None, accumulate_grad_batches=1, amp_backend='native', amp_level='O2', auto_lr_find=False, auto_scale_batch_size=False, auto_select_gpus=False, automatic_optimization=None, batch_size=96, benchmark=False, chat=True, check_val_every_n_epoch=1, checkpoint_callback=True, data_path='Chatbot_data/ChatbotData.csv', default_root_dir=None, deterministic=False, distributed_backend=None, enable_pl_optimizer=None, fast_dev_run=False, flush_logs_every_n_steps=100, gpus=1, gradient_clip_val=0, limit_predict_batches=1.0, limit_test_batches=1.0, limit_train_batches=1.0, limit_val_batches=1.0, log_every_n_steps=50, log_gpu_memory=None, logger=True, lr=5e-05, max_epochs=None, max_len=32, max_steps=None, min_epochs=None, min_steps=None, model_params='/content/drive/MyDrive/cd_ai/s4p/model_best.ckpt', move_metrics_to_cpu=False, multiple_trainloader_mode='max_size_cycle', num_nodes=1, num_processes=1, num_sanity_val_steps=2, overfit_batches=0.0, plugins=None, precision=32, prepare_data_per_node=True, process_position=0, profiler=None, progress_bar_refresh_rate=None, reload_dataloaders_every_epoch=False, replace_sampler_ddp=True, resume_from_checkpoint=None, sentiment='0', stochastic_weight_avg=False, sync_batchnorm=False, terminate_on_nan=False, tpu_cores=None, track_grad_norm=-1, train=False, truncated_bptt_steps=None, val_check_interval=1.0, warmup_ratio=0.1, weights_save_path=None, weights_summary='top')
# user > 안녕하세요
# Simsimi > 안녕하세요.
# user > 반갑습니다
# Simsimi > 반갑습니다.
# user > 이름이 뭐에요?
# Simsimi > 디어 달링 워터젤 틴트 수박레드에요!
# user > 그렇군요.
# Simsimi > 부산 코믹 월드 가고 싶어요. 닐구 전용 기차가 필요해요.
# user > 혼자 가세요.
# Simsimi > 누가요?
# user > 당신이요.
# Simsimi > 나두 당신이 이러니까 아주 되게 좋다.
# user > quit
